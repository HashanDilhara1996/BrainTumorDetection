# %%
import numpy as np 
import pandas as pd 
import os
from os import listdir
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import imutils
import time

from tensorflow.keras.models import Model,load_model
from tensorflow.keras.layers import Conv2D,Input,ZeroPadding2D,BatchNormalization,Flatten,Activation,Dense,MaxPooling2D
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle #shuffling the data improves the model
from keras.callbacks import ModelCheckpoint

# %%
image_dir="./brain_tumor_dataset/"

# %%
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60.
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)

# %%
def crop_brain_image(image, plot=False):
    
    # Convert the image to grayscale, and blur it slightly
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray, (5, 5), 0)
    
    thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
    thresh = cv2.erode(thresh, None, iterations=2)
    thresh = cv2.dilate(thresh, None, iterations=2)

    # Find contours in thresholded image, then grab the largest one
    cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    c = max(cnts, key=cv2.contourArea)
    # extreme points
    extLeft = tuple(c[c[:, :, 0].argmin()][0])
    extRight = tuple(c[c[:, :, 0].argmax()][0])
    extTop = tuple(c[c[:, :, 1].argmin()][0])
    extBot = tuple(c[c[:, :, 1].argmax()][0])
    
    # crop new image out of the original image using the four extreme points (left, right, top, bottom)
    new_image = image[extTop[1]:extBot[1], extLeft[0]:extRight[0]]            

    if plot:
        plt.figure()
        plt.subplot(1, 2, 1)
        plt.imshow(image)
        plt.tick_params(axis='both', which='both', top=False, bottom=False, left=False, right=False,labelbottom=False, labeltop=False, labelleft=False, labelright=False)
        plt.title('Original Image')
        plt.subplot(1, 2, 2)
        plt.imshow(new_image)
        plt.tick_params(axis='both', which='both',top=False, bottom=False, left=False, right=False,labelbottom=False, labeltop=False, labelleft=False, labelright=False)
        plt.title('Cropped Image')
        plt.show()
    
    return new_image

# %%
test_img = cv2.imread(image_dir+'yes/Y107.jpg')
test_crop_img = crop_brain_image(test_img, True)

# %%
def loading_data(dir_list, image_size):

    X = []
    y = []
    image_width, image_height = image_size
    
    for directory in dir_list:
        for filename in listdir(directory):
            image = cv2.imread(directory+'/'+filename)
            image = crop_brain_image(image, plot=False)
            image = cv2.resize(image, dsize=(image_width, image_height), interpolation=cv2.INTER_CUBIC)
            # normalizing values
            image = image / 255.
            X.append(image)
            
            if directory[-3:] == 'yes':
                y.append([1])
            else:
                y.append([0])
                
    X = np.array(X)
    y = np.array(y)
    
    # Shuffle the data
    X, y = shuffle(X, y)
    
    print(f'Number of examples is: {len(X)}')
    print(f'X shape is: {X.shape}')
    print(f'y shape is: {y.shape}')
    
    return X, y

# %%
augmented_data_path ='./brain_tumor_dataset/augmented-images/'

augmented_yes =augmented_data_path+'yes'
augmented_no = augmented_data_path+'no'

IMG_WIDTH, IMG_HEIGHT = (240, 240)

X, y = loading_data([augmented_yes, augmented_no], (IMG_WIDTH, IMG_HEIGHT))
# Out:
# Number of examples is: 2064
# X shape is: (2064, 240, 240, 3)
# y shape is: (2064, 1)

# %%
def plot_sample_images(X, y, n=40):
    for label in [0,1]:
        
        images = X[np.argwhere(y == label)]
        n_images = images[:n]
        
        columns_n = 10
        rows_n = int(n/ columns_n)

        plt.figure(figsize=(10, 8))
        
        i = 1 # current plot        
        for image in n_images:
            plt.subplot(rows_n, columns_n, i)
            plt.imshow(image[0])
            
            # remove ticks
            plt.tick_params(axis='both', which='both', 
                            top=False, bottom=False, left=False, right=False,
                           labelbottom=False, labeltop=False, labelleft=False, labelright=False)
            
            i += 1
        
        label_to_str = lambda label: "Yes" if label == 1 else "No"
        plt.suptitle(f"Brain Tumor: {label_to_str(label)}")
        plt.show()

# %%
plot_sample_images(X, y)

# %%
def split_data(X, y, test_size=0.2):
       
    X_train, X_test_val, y_train, y_test_val = train_test_split(X, y, test_size=test_size)
    X_test, X_val, y_test, y_val = train_test_split(X_test_val, y_test_val, test_size=0.5)
    
    return X_train, y_train, X_val, y_val, X_test, y_test

# %%
X_train, y_train, X_val, y_val, X_test, y_test = split_data(X, y, test_size=0.3)

# %%
print ("Number of training examples = " + str(X_train.shape[0]))
print ("Number of validation examples = " + str(X_val.shape[0]))
print ("Number of test examples = " + str(X_test.shape[0]))
# Out:
# Number of training examples = 1444
# Number of validation examples = 310
# Number of test examples = 310

# %% [markdown]
# # Model Building

# %%
def building_model(input_shape):
    X_input = Input(input_shape) 
    X = ZeroPadding2D((2, 2))(X_input) 
    
    X = Conv2D(32, (7, 7), strides = (1, 1), name = 'conv0')(X)
    X = BatchNormalization(axis = 3, name = 'bn0')(X)
    X = Activation('relu')(X) 
    
    X = MaxPooling2D((4, 4), name = 'max_pool0')(X) 
    X = MaxPooling2D((4, 4), name = 'max_pool1')(X) 
    X = Flatten()(X) 
    X = Dense(1, activation='sigmoid', name = 'Fc')(X) 
    model = Model(inputs = X_input, outputs = X, name = 'BrainTumorDetectionModel')
    
    return model

# %%
IMG_SHAPE = (IMG_WIDTH, IMG_HEIGHT, 3)
model=building_model(IMG_SHAPE)
model.summary()
# Out:
# Model: "BrainTumorDetectionModel"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 240, 240, 3)]     0
#
#  zero_padding2d (ZeroPadding  (None, 244, 244, 3)      0
#  2D)
#
#  conv0 (Conv2D)              (None, 238, 238, 32)      4736
#
#  bn0 (BatchNormalization)    (None, 238, 238, 32)      128
#
#  activation (Activation)     (None, 238, 238, 32)      0
#
#  max_pool0 (MaxPooling2D)    (None, 59, 59, 32)        0
#
#  max_pool1 (MaxPooling2D)    (None, 14, 14, 32)        0
#
#  flatten (Flatten)           (None, 6272)              0
#
#  Fc (Dense)                  (None, 1)                 6273
#
# =================================================================
# Total params: 11,137
# Trainable params: 11,073
# Non-trainable params: 64
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
start_time = time.time()

checkpoint = ModelCheckpoint('model-{epoch:03d}.model', monitor='val_loss', verbose=0, save_best_only=True, mode='auto')
model.fit(x=X_train, y=y_train, batch_size=32, epochs=30, validation_data=(X_val, y_val), callbacks=[checkpoint])

end_time = time.time()
execution_time = (end_time - start_time)
print(f"Elapsed Time: {format(hms_string(execution_time))}")
# Out:
# Epoch 1/30
# 46/46 [==============================] - ETA: 0s - loss: 0.8956 - accuracy: 0.6145INFO:tensorflow:Assets written to: model-001.model\assets
# 46/46 [==============================] - 52s 1s/step - loss: 0.8956 - accuracy: 0.6145 - val_loss: 0.6488 - val_accuracy: 0.6161
# Epoch 2/30
# 46/46 [==============================] - ETA: 0s - loss: 0.4922 - accuracy: 0.7585INFO:tensorflow:Assets written to: model-002.model\assets
# 46/46 [==============================] - 53s 1s/step - loss: 0.4922 - accuracy: 0.7585 - val_loss: 0.6095 - val_accuracy: 0.7097
# Epoch 3/30
# 46/46 [==============================] - ETA: 0s - loss: 0.4412 - accuracy: 0.7917INFO:tensorflow:Assets written to: model-003.model\assets
# 46/46 [==============================] - 54s 1s/step - loss: 0.4412 - accuracy: 0.7917 - val_loss: 0.5764 - val_accuracy: 0.7258
# Epoch 4/30
# 46/46 [==============================] - ETA: 0s - loss: 0.3681 - accuracy: 0.8471INFO:tensorflow:Assets written to: model-004.model\assets
# 46/46 [==============================] - 51s 1s/step - loss: 0.3681 - accuracy: 0.8471 - val_loss: 0.5282 - val_accuracy: 0.7742
# Epoch 5/30
# 46/46 [==============================] - ETA: 0s - loss: 0.3825 - accuracy: 0.8360INFO:tensorflow:Assets written to: model-005.model\assets
# 46/46 [==============================] - 51s 1s/step - loss: 0.3825 - accuracy: 0.8360 - val_loss: 0.5150 - val_accuracy: 0.7581
# Epoch 6/30
# 46/46 [==============================] - 50s 1s/step - loss: 0.2945 - accuracy: 0.8844 - val_loss: 0.5921 - val_accuracy: 0.6871
# Epoch 7/30
# 46/46 [==============================] - ETA: 0s - loss: 0.2795 - accuracy: 0.8900INFO:tensorflow:Assets written to: model-007.model\assets
# 46/46 [==============================] - 50s 1s/step - loss: 0.2795 - accuracy: 0.8900 - val_loss: 0.4184 - val_accuracy: 0.8161
# Epoch 8/30
# 46/46 [==============================] - ETA: 0s - loss: 0.3061 - accuracy: 0.8657INFO:tensorflow:Assets written to: model-008.model\assets
# 46/46 [==============================] - 51s 1s/step - loss: 0.3061 - accuracy: 0.8657 - val_loss: 0.3951 - val_accuracy: 0.8323
# Epoch 9/30
# 46/46 [==============================] - 49s 1s/step - loss: 0.3394 - accuracy: 0.8491 - val_loss: 0.3974 - val_accuracy: 0.8258
# Epoch 10/30
# 46/46 [==============================] - 51s 1s/step - loss: 0.2350 - accuracy: 0.9107 - val_loss: 0.5141 - val_accuracy: 0.7484
# Epoch 11/30
# 46/46 [==============================] - 48s 1s/step - loss: 0.2142 - accuracy: 0.9218 - val_loss: 0.4264 - val_accuracy: 0.8290
# Epoch 12/30
# 46/46 [==============================] - 49s 1s/step - loss: 0.2063 - accuracy: 0.9183 - val_loss: 0.4483 - val_accuracy: 0.8226
# Epoch 13/30
# 46/46 [==============================] - 49s 1s/step - loss: 0.1890 - accuracy: 0.9273 - val_loss: 0.4800 - val_accuracy: 0.8194
# Epoch 14/30
# 46/46 [==============================] - 49s 1s/step - loss: 0.2230 - accuracy: 0.9142 - val_loss: 0.4615 - val_accuracy: 0.8161
# Epoch 15/30
# 46/46 [==============================] - 48s 1s/step - loss: 0.2335 - accuracy: 0.9100 - val_loss: 0.4787 - val_accuracy: 0.8323
# Epoch 16/30
# 46/46 [==============================] - ETA: 0s - loss: 0.1625 - accuracy: 0.9446INFO:tensorflow:Assets written to: model-016.model\assets
# 46/46 [==============================] - 50s 1s/step - loss: 0.1625 - accuracy: 0.9446 - val_loss: 0.3649 - val_accuracy: 0.8581
# Epoch 17/30
# 46/46 [==============================] - 49s 1s/step - loss: 0.1630 - accuracy: 0.9433 - val_loss: 0.3896 - val_accuracy: 0.8484
# Epoch 18/30
# 46/46 [==============================] - 49s 1s/step - loss: 0.1358 - accuracy: 0.9550 - val_loss: 0.4285 - val_accuracy: 0.8419
# Epoch 19/30
# 46/46 [==============================] - 48s 1s/step - loss: 0.1343 - accuracy: 0.9606 - val_loss: 0.3760 - val_accuracy: 0.8548
# Epoch 20/30
# 46/46 [==============================] - 49s 1s/step - loss: 0.1225 - accuracy: 0.9654 - val_loss: 0.3722 - val_accuracy: 0.8677
# Epoch 21/30
# 46/46 [==============================] - 53s 1s/step - loss: 0.1236 - accuracy: 0.9606 - val_loss: 0.5484 - val_accuracy: 0.8194
# Epoch 22/30
# 46/46 [==============================] - 53s 1s/step - loss: 0.1032 - accuracy: 0.9723 - val_loss: 0.4135 - val_accuracy: 0.8548
# Epoch 23/30
# 46/46 [==============================] - ETA: 0s - loss: 0.0983 - accuracy: 0.9758INFO:tensorflow:Assets written to: model-023.model\assets
# 46/46 [==============================] - 53s 1s/step - loss: 0.0983 - accuracy: 0.9758 - val_loss: 0.3590 - val_accuracy: 0.8806
# Epoch 24/30
# 46/46 [==============================] - 48s 1s/step - loss: 0.0880 - accuracy: 0.9827 - val_loss: 0.3678 - val_accuracy: 0.8774
# Epoch 25/30
# 46/46 [==============================] - 50s 1s/step - loss: 0.0958 - accuracy: 0.9765 - val_loss: 0.4815 - val_accuracy: 0.8419
# Epoch 26/30
# 46/46 [==============================] - 50s 1s/step - loss: 0.1355 - accuracy: 0.9536 - val_loss: 0.4319 - val_accuracy: 0.8484
# Epoch 27/30
# 46/46 [==============================] - 50s 1s/step - loss: 0.0758 - accuracy: 0.9841 - val_loss: 0.7086 - val_accuracy: 0.7839
# Epoch 28/30
# 46/46 [==============================] - 48s 1s/step - loss: 0.1039 - accuracy: 0.9689 - val_loss: 0.3970 - val_accuracy: 0.8645
# Epoch 29/30
# 46/46 [==============================] - 51s 1s/step - loss: 0.0763 - accuracy: 0.9813 - val_loss: 0.4635 - val_accuracy: 0.8548
# Epoch 30/30
# 46/46 [==============================] - 50s 1s/step - loss: 0.0606 - accuracy: 0.9896 - val_loss: 0.4057 - val_accuracy: 0.8806
# Elapsed Time: 0:25:06.48

# %% [markdown]
# # Model Evaluation

# %%
history = model.history.history

# %%
def plot_metrics(history):
    
    train_loss = history['loss']
    val_loss = history['val_loss']
    train_acc = history['accuracy']
    val_acc = history['val_accuracy']
    
    # Loss
    plt.figure()
    plt.plot(train_loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Loss')
    plt.legend()
    plt.show()
    
    # Accuracy
    plt.figure()
    plt.plot(train_acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Accuracy')
    plt.legend()
    plt.show()

# %%
plot_metrics(history)

# %%
from sklearn.metrics import f1_score
best_model = load_model(filepath='model-023.model')

# %%
from sklearn.metrics import accuracy_score

predictions = best_model.predict(X_train)
predictions = [1 if x>0.5 else 0 for x in predictions]

accuracy = accuracy_score(y_train, predictions)
print('Val Accuracy = %.2f' % accuracy)
# Out:
# Val Accuracy = 0.87
